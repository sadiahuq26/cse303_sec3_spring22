# %%
from google.colab import files

# %%
# !cp /content/drive/MyDrive/2019-1-60-034_Lab_Assignment01_on_Lab04/module.py /content

# %%
import module as m

# %%
# Student ID: 2019-1-60-034
# Student Name: Sadia Huq
# Lab Assignment - 1
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/2019-1-60-034_Lab_Assignment01_on_Lab04/dataset_lab04.csv')
#df.info()

# %% [markdown]
# 1) How many rows and columns this dataframe has? Print this information.

# %%
def lab04_task1_2019_1_60_034():
 print ('Number of rows: ', df.shape[0])
 print ('Number of columns: ', df.shape[1])
lab04_task1_2019_1_60_034()
# Out:
# Number of rows:  284807
# Number of columns:  31

# %% [markdown]
# 2) Describe (numerical summary) the time and amount column. Print this information.

# %%
def lab04_task2_2019_1_60_034():
 print(df[['Time', 'Amount']].describe())
lab04_task2_2019_1_60_034()
# Out:
#                 Time         Amount
# count  284807.000000  284807.000000
# mean    94813.859575      88.349619
# std     47488.145955     250.120109
# min         0.000000       0.000000
# 25%     54201.500000       5.600000
# 50%     84692.000000      22.000000
# 75%    139320.500000      77.165000
# max    172792.000000   25691.160000

# %% [markdown]
# 3) There are 31 columns in the dataset. Compute some statistical measures like mean, median, standard deviation,
# variance using Pandas Function for at least two columns.
# Print this information.

# %%
def lab04_task3_2019_1_60_034():
 Time = df['Time']
 print("Time Mean: " ,Time.mean())
 print("Time Standard Deviation: ",Time.std())
 print("Time Variance: ",Time.var())
 print("Time Lower Quartile: " ,Time.quantile(0.25))
 print("Time Median: " ,Time.median())
 print("Time Upper Quartile: " ,Time.quantile(0.75))
 print("Time Skewness: " ,Time.skew())
 print("Time Kurtosis: " ,Time.kurt())
 print("Time Min: ",Time.min())
 print("Time Max: ",Time.max())
 
 Amount = df['Amount']
 print("Amount Mean: " ,Amount.mean())
 print("Amount Standard Deviation: ",Amount.std())
 print("Amount Variance: ",Amount.var())
 print("Amount Lower Quartile: " ,Amount.quantile(0.25))
 print("Amount Median: " ,Amount.median())
 print("Amount Upper Quartile: " ,Amount.quantile(0.75))
 print("Amount Skewness: " ,Amount.skew())
 print("Amount Kurtosis: " ,Amount.kurt())
 print("Amount Min: ",Amount.min())
 print("Amount Max: ",Amount.max())
lab04_task3_2019_1_60_034()
# Out:
# Time Mean:  94813.85957508067
# Time Standard Deviation:  47488.14595456582
# Time Variance:  2255124006.202146
# Time Lower Quartile:  54201.5
# Time Median:  84692.0
# Time Upper Quartile:  139320.5
# Time Skewness:  -0.0355676180063216
# Time Kurtosis:  -1.2935300508989838
# Time Min:  0.0
# Time Max:  172792.0
# Amount Mean:  88.34961925087359
# Amount Standard Deviation:  250.1201092402221
# Amount Variance:  62560.069046340635
# Amount Lower Quartile:  5.6
# Amount Median:  22.0
# Amount Upper Quartile:  77.16499999999999
# Amount Skewness:  16.977724453761024
# Amount Kurtosis:  845.0926455465277
# Amount Min:  0.0
# Amount Max:  25691.16

# %% [markdown]
# 4) Show the Box Plot of Time and Amount column. Also print the value of Q1, Median, Q3, IQR. Are there any outliers? Explain your answer and print it.

# %%
def lab04_task4_2019_1_60_034():
 df.boxplot(column = ['Time','Amount'])
 Time = df['Time']
 Amount = df['Amount']
 print("Time Lower Quartile Q1: " ,Time.quantile(0.25))
 print("Time Median Q2: ",Time.median())
 print("Time Upper Quartile Q3: " ,Time.quantile(0.75))
 IQR1=  m.IQR(Time)
 print("Time Interquartile range(IQR) : ",IQR1)
    
 print("Amount Lower Quartile Q1: " ,Amount.quantile(0.25))
 print("Amount Median Q2: " ,Amount.median())
 print("Amount Upper Quartile Q3: " ,Amount.quantile(0.75))
 IQR2=  m.IQR(Amount)
 print("Amount Interquartile range(IQR) : ",IQR2)
 m.Whiskers(Time,IQR1)
 m.Whiskers(Amount,IQR2)
lab04_task4_2019_1_60_034()
# Out:
# Time Lower Quartile Q1:  54201.5
# Time Median Q2:  84692.0
# Time Upper Quartile Q3:  139320.5
# Time Interquartile range(IQR) :  85119.0
# Amount Lower Quartile Q1:  5.6
# Amount Median Q2:  22.0
# Amount Upper Quartile Q3:  77.16499999999999
# Amount Interquartile range(IQR) :  71.565
# upper whisker :  266999.0
# lower whisker :  -73477.0
# Min:  0.0
# Max:  172792.0
# There is no outliers
# upper whisker :  184.5125
# lower whisker :  -101.7475
# Min:  0.0
# Max:  25691.16
# There is no outliers

# %% [markdown]
# 5) Show the Histogram of Time and Amount column. Print the value of the Skewness and Kurtosis using
# appropriate Pandas functions. Comment on the type of the data distribution and print it.

# %%
def lab04_task5_2019_1_60_034():
 df.hist(column = ["Time", "Amount"], bins = 5,color='blue')
 Time = df['Time']
 print("Skewness of time: " , Time.skew()) 
 print("Kurtosis of time: " , Time.kurt()) 
 print("\n")
 m.skewness(Time)
 m.kurtosis(Time)
 Amount = df['Amount']
 print("Skewness of amount: " , Amount.skew())  
 print("Kurtosis of amount: " , Amount.kurt())
 m.skewness(Amount)
 m.kurtosis(Amount)
lab04_task5_2019_1_60_034()
# Out:
# Skewness of time:  -0.0355676180063216
# Kurtosis of time:  -1.2935300508989838
#
#
# Skewness of amount:  16.977724453761024
# Kurtosis of amount:  845.0926455465277

# %% [markdown]
# 6) Find the percentage of records with class value = 0 (Non-Fraudulent) and class value = 1 (Fraudulent).
# Print this information.

# %%
def lab04_task6_2019_1_60_034():
 class0 = len(df[df['Class']==0])*100
 class1 = len(df[df['Class']==1])*100
 print("Percentage of class value 0 :",class0/len(df['Class']))
 print("Percentage of class value 1 :",class1/len(df['Class']))
lab04_task6_2019_1_60_034()
# Out:
# Percentage of class value 0 : 99.827251436938
# Percentage of class value 1 : 0.1727485630620034

# %% [markdown]
# 7) Show the result you have got in 6 using a Histogram.

# %%
def lab04_task7_2019_1_60_034():
 df_histo = df[['Class']]
 df_histo.hist(column = ['Class'], bins = 5)
lab04_task7_2019_1_60_034()

# %% [markdown]
# 8) Show the result you have got in 6 using a Bar chart. Create the bar chart on the percentage value, not
# on the total number of occurrences.

# %%
import matplotlib.pyplot as p
def lab04_task8_2019_1_60_034():
  Non_Fraudulent = (df.loc[df['Class']==0])*100
  Fraudulent = (df.loc[df['Class']==1])*100
  a=Non_Fraudulent.size/df.size
  b=Fraudulent.size/df.size
  x=[0,1]
  y=[a,b]
  x1_tick = ['a','b']
  p.bar(x,y, tick_label= x1_tick)
  p.xlabel('class')
  p.ylabel('percentage')
  p.show()
lab04_task8_2019_1_60_034()

# %% [markdown]
# 9) Show the Histrogram (data distribution) of a few other columns (your choice) showing both positive
# and negative skew and also leptokurtic and platykurtic data distribution. So, you should display at least
# four Histograms.

# %%
def lab04_task9_2019_1_60_034():
  df.hist(column = ["V3","V10", "V8", "V12"], bins = 5)
  print("Skewness of V3 :",df['V3'].skew()) 
  print("Kurtosis of V10 :",df['V10'].kurt()) 
  print("V3 Skewness using assign module: ", m.skewness(df['V3'])) 
  print("V10 Kurtosis using assign module: ", m.kurtosis(df['V10']))
  print("Skewness of V8 :",df['V8'].skew()) 
  print("Kurtosis of V12 :",df['V12'].kurt()) 
  print("V28 Skewness using assign module: ", m.skewness(df['V8'])) 
  print("V12 Kurtosis using assign module: ", m.kurtosis(df['V12']))
lab04_task9_2019_1_60_034()
# Out:
# Skewness of V3 : -2.2401554402404193
# Kurtosis of V10 : 31.98823877949119
# V3 Skewness using assign module:  As skewness of time is less than 0,
# we can see data distribution curve is negatively or left skewed.
# V10 Kurtosis using assign module:  As kurtosis of time is greater than 3, it is called leptokurtosis.
#
# Skewness of V8 : -8.521944194777976
# Kurtosis of V12 : 20.241869662225426
# V28 Skewness using assign module:  As skewness of time is less than 0,
# we can see data distribution curve is negatively or left skewed.
# V12 Kurtosis using assign module:  As kurtosis of time is greater than 3, it is called leptokurtosis.

# %% [markdown]
# 10) Find the highest positive correlation among all attributes. While finding the correlation, use appropriate
# code, not manually. Print this information accordingly.

# %%
def lab04_task10_2019_1_60_034():
  correlation= df.corr()
  positive_correlation= correlation[correlation>0]
  st=positive_correlation.unstack()
  sort= st.sort_values(kind="quicksort", ascending=False)
  print(sort)
  print('Highest correlation: ')
  result1=sort[32:33]
  print(result1)
lab04_task10_2019_1_60_034()
# Out:
# Time   Time    1.0
# V3     V3      1.0
# V5     V5      1.0
# V6     V6      1.0
# V7     V7      1.0
#               ...
# Class  V16     NaN
#        V17     NaN
#        V18     NaN
#        V23     NaN
#        V24     NaN
# Length: 961, dtype: float64
# Highest correlation:
# Amount  V7    0.397311
# dtype: float64

# %% [markdown]
# 11) Support your findings in Question 10 using a Scatter Plot.

# %%
def lab04_task11_2019_1_60_034():
  correlation= df.corr()
  positive_correlation= correlation[correlation>0]
  positive_correlation.plot.scatter(x='Amount',y='V7')
lab04_task11_2019_1_60_034()

# %% [markdown]
# 12) Find the highest negative correlation among all attributes. While finding the correlation, use
# appropriate code, not manually. Print this information accordingly.

# %%
def lab04_task12_2019_1_60_034():
  correlation= df.corr()
  negative_correlation= correlation[correlation<0]
  st=negative_correlation.unstack()
  sort= st.sort_values(kind="quicksort", ascending=False)
  print(sort)
  print('Highest negative correlation: ')
  print(sort[1:2])
lab04_task12_2019_1_60_034()
# Out:
# V22    V6       -4.705235e-19
# V6     V22      -4.705235e-19
# V4     V28      -2.761403e-18
# V28    V4       -2.761403e-18
# V12    V7       -3.536655e-18
#                      ...
# Class  V26                NaN
#        V27                NaN
#        V28                NaN
#        Amount             NaN
#        Class              NaN
# Length: 961, dtype: float64
# Highest negative correlation:
# V6  V22   -4.705235e-19
# dtype: float64

# %% [markdown]
# 13) Support your findings in Question 12 using a Scatter Plot.

# %%
def lab04_task13_2019_1_60_034():
  correlation= df.corr()
  negative_correlation= correlation[correlation<0]
  negative_correlation.plot.scatter(x ='V6', y= 'V22')
lab04_task13_2019_1_60_034()

# %% [markdown]
# 14) Create a Box Plot of the Amount Column.

# %%
def lab04_task14_2019_1_60_034():
  df.boxplot(column = ['Amount'])
lab04_task14_2019_1_60_034()

# %% [markdown]
# 15) Now create two other box plots side by side. The first one will show the Amount column value for
# which the class value = 0 (Non-Fraudulent) and the second one will show the Amount column value
# for which the class value = 1 (Fraudulent). Do you find any particular pattern by just considering
# Amount column. Explain your answer and print it accordingly.

# %%
def lab04_task15_2019_1_60_034():
  Non_Fraudulent =df[['Amount', 'Class']].query('Class == 0')
  amountClass0 = Non_Fraudulent['Amount']
  Fraudulent =df[['Amount', 'Class']].query('Class == 1')
  amountClass1 = Fraudulent['Amount']
  columns = [amountClass0, amountClass1]
  fig,df1 = p.subplots()
  df1.boxplot(columns)
  p.show()  
  print("Amount_Class0 Lower Quartile,Q1: " ,amountClass0.quantile(0.25))
  print("Amount_Class0 Median,Q2: ",amountClass0.median())
  print("Amount_Class0 Upper Quartile,Q3: " ,amountClass0.quantile(0.75))
  IQR3= m.IQR(amountClass0)
  print("Amount_Class0 Interquartile range(IQR) : ",IQR3)
  print("Amount_Class1 Lower Quartile,Q1: " ,amountClass1.quantile(0.25))
  print("Amount_Class1 Median Q2: " ,amountClass1.median())
  print("Amount_Class1 Upper Quartile Q3: " ,amountClass1.quantile(0.75))
  IQR4= m.IQR(amountClass1)
  print("Amount_Class1 Interquartile range(IQR) : ",IQR4)
  print("\n")
  print("Amount_Class0 informations: \n")
  m.Whiskers(amountClass0,IQR3)
  print("\n")
  print("Amount_Class1 informations: \n")
  m.Whiskers(amountClass1,IQR4)
  print("\nIn these 2 pattern ,1st one which is for class 0 has lots of data. In our dataset all rows are from class 0.")
  print("And in the 2nd plot 2,is forfradulent class 1,which is al,ost 0,the box plot is very small.\nSo non-fradulent and fradulent collumn class hasbig difference")
  print("Now we can say that there is almost no row for amount where class is 0")
lab04_task15_2019_1_60_034()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Amount_Class0 Lower Quartile,Q1:  5.65
# Amount_Class0 Median,Q2:  22.0
# Amount_Class0 Upper Quartile,Q3:  77.05
# Amount_Class0 Interquartile range(IQR) :  71.39999999999999
# Amount_Class1 Lower Quartile,Q1:  1.0
# Amount_Class1 Median Q2:  9.25
# Amount_Class1 Upper Quartile Q3:  105.89
# Amount_Class1 Interquartile range(IQR) :  104.89
#
#
# Amount_Class0 informations:
#
# upper whisker :  184.14999999999998
# lower whisker :  -101.44999999999999
# Min:  0.0
# Max:  25691.16
# There is no outliers
#
#
# Amount_Class1 informations:
#
# upper whisker :  263.225
# ...
