# %% [markdown]
# <a href="https://colab.research.google.com/github/sadiahuq26/cse303_sec3_spring22/blob/main/2019_1_60_034_lab06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Activity 1: Basic Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#x-axis values
x = np.array([1,2,3])
#corresponding y axis values
y = np.array([2,4,1])

z =  np.array([4,2,3])

# %%
#plotting the points
plt.plot(x,y)
#naming the x axis
plt.xlabel('x - axis')
#naming the y axis
plt.ylabel('y - axis')
#giving title to my graph
plt.title('My first graph!')
plt.show()

# %% [markdown]
# Activity 1: Views

# %%
import matplotlib.pyplot as plt

# %%
left = [1,2,3,4,5]
height = [10,24,36,40,5]
tick_label = ['one', 'two', 'three', 'four', 'five']

# %%
plt.bar(left, height, tick_label = tick_label, width = 0.8, color = ['red', 'green'])
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('My bar chaRT!')
plt.show()

# %% [markdown]
# ACTIVITY 2: useful line properties

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6), dpi=80)

# %%
plt.subplot(1,1,1)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend(loc = 'upper left')
plt.title('Sine and Cosine Graph')
plt.savefig('sample.png', dpi=72)
plt.show()

# %% [markdown]
# activity 3

# %%
plt.subplot(1,1,1)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.legend(loc = 'upper left')
plt.title('Sine and Cosine Graph')
plt.savefig('sample.png', dpi=72)
plt.show()

# %% [markdown]
# activity 4

# %%
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color = 'blue', linewidth=2.5, linestyle = '--')
plt.scatter([t,t],[0,np.cos(t)], 50, color = 'blue')
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$', xy=(t, np.sin(t)), xycoords='data', xytext=(+10, +30),textcoords='offset points', fontsize = 16, arrowprops = dict(arrowstyle = '->', connectionstyle='arc3, rad=.2'))
plt.plot([t,t], [0,np.sin(t)], color = 'red', linewidth = 2.5, linestyle = '--')
plt.scatter([t,t],[0,np.sin(t)], 50, color='red')
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',xy=(t, np.sin(t)), xycoords='data', xytext=(-90, -50),textcoords='offset points', fontsize = 16, arrowprops = dict(arrowstyle = '->', connectionstyle='arc3, rad=.2'))
# Out:
# Text(-90, -50, '$\\cos(\\frac{2\\pi}{3})=-\\frac{1}{2}$')

# %% [markdown]
# activity 5

# %%
#sub plot with 2 rows and 1 column
plt.subplot(2,1,1)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
#plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.subplot(2,1,2)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
#plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.show()

# %%
#sub plot with 2 rows and 2 column
plt.subplot(2,2,1)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
#plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.subplot(2,2,2)
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
#plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.subplot(2,2,3)
t = 2*np.pi/3
plt.plot([t,t],[0,np.cos(t)], color = 'blue', linewidth=2.5, linestyle = '--')
plt.scatter([t,t],[0,np.cos(t)], 50, color = 'blue')
plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$', xy=(t, np.sin(t)), xycoords='data', xytext=(+10, +30),textcoords='offset points', fontsize = 16, arrowprops = dict(arrowstyle = '->', connectionstyle='arc3, rad=.2'))
plt.subplot(2,2,4)
plt.plot([t,t], [0,np.sin(t)], color = 'red', linewidth = 2.5, linestyle = '--')
plt.scatter([t,t],[0,np.sin(t)], 50, color='red')
plt.annotate(r'$\cos(\frac{2\pi}{3})=-\frac{1}{2}$',xy=(t, np.sin(t)), xycoords='data', xytext=(-90, -50),textcoords='offset points', fontsize = 16, arrowprops = dict(arrowstyle = '->', connectionstyle='arc3, rad=.2'))


plt.show()

# %% [markdown]
# activity 6

# %%
plt.axes([0.1,0.1,.8,.8])
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
#plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.axes([0.2,0.2,.3,.3])
X = np.linspace(-np.pi, np.pi, 256, endpoint= True)
C, S = np.cos(X), np.sin(X)
#plt.plot(X, C, color ='blue', linewidth = 1.0, linestyle= '-', label = 'cosine')
plt.plot(X, S, color ='green', linewidth = 1.0, linestyle= '-', label = 'sine')
plt.xlim(-4.0, 4.0)
plt.xticks(np.linspace(-4, 4, 9, endpoint= True))
plt.ylim(-1.0, 1.0)
plt.yticks(np.linspace(-1, 1, 5, endpoint= True))
plt.xlabel('x - axis')
plt.ylabel('y - axis')

plt.show()

# %% [markdown]
# activity 7

# %%
plt.scatter(x,y)
plt.bar(x,y)
plt.pei(z)
axes = gca()
      axes.set_xlim(0,4)
      axes.set_ylim(0,3)
      axes.set_xticklabels([])
      axes.set_yticklabels([])
      show()
