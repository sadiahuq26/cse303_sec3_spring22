# %%
from google.colab import files

# %%
# !cp /content/drive/MyDrive/2019-1-60-034_Lab04/module4.py /content

# %%
import module4 as m

# %% [markdown]
# 1) How many rows and columns this dataframe has?

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/2019-1-60-034_Lab04/dataset_lab04.csv')
print('Number of rows: ',df.shape[0])
print('Numbber of columns:',df.shape[1])
# Out:
# Number of rows:  284807
# Numbber of columns: 31

# %% [markdown]
# 2) Describe (numerical summary) the time and amount column.

# %%
print(df[['Time', 'Amount']].describe())
# Out:
#                 Time         Amount
# count  284807.000000  284807.000000
# mean    94813.859575      88.349619
# std     47488.145955     250.120109
# min         0.000000       0.000000
# 25%     54201.500000       5.600000
# 50%     84692.000000      22.000000
# 75%    139320.500000      77.165000
# max    172792.000000   25691.160000

# %% [markdown]
# 3) There are 31 columns in the dataset. Compute some statistical measures like mean, median, standard
# deviation, variance using Pandas Function.

# %%
 Time = df['Time']
 print("Time Mean: " ,Time.mean())
 print("Time Standard Deviation: ",Time.std())
 print("Time Variance: ",Time.var())
 print("Time Lower Quartile: " ,Time.quantile(0.25))
 print("Time Median: " ,Time.median())
 print("Time Upper Quartile: " ,Time.quantile(0.75))
 print("Time Skewness: " ,Time.skew())
 print("Time Kurtosis: " ,Time.kurt())
 print("Time Min: ",Time.min())
 print("Time Max: ",Time.max())
 
 Amount = df['Amount']
 print("Amount Mean: " ,Amount.mean())
 print("Amount Standard Deviation: ",Amount.std())
 print("Amount Variance: ",Amount.var())
 print("Amount Lower Quartile: " ,Amount.quantile(0.25))
 print("Amount Median: " ,Amount.median())
 print("Amount Upper Quartile: " ,Amount.quantile(0.75))
 print("Amount Skewness: " ,Amount.skew())
 print("Amount Kurtosis: " ,Amount.kurt())
 print("Amount Min: ",Amount.min())
 print("Amount Max: ",Amount.max())
# Out:
# Time Mean:  94813.85957508067
# Time Standard Deviation:  47488.14595456582
# Time Variance:  2255124006.202146
# Time Lower Quartile:  54201.5
# Time Median:  84692.0
# Time Upper Quartile:  139320.5
# Time Skewness:  -0.0355676180063216
# Time Kurtosis:  -1.2935300508989838
# Time Min:  0.0
# Time Max:  172792.0
# Amount Mean:  88.34961925087359
# Amount Standard Deviation:  250.1201092402221
# Amount Variance:  62560.069046340635
# Amount Lower Quartile:  5.6
# Amount Median:  22.0
# Amount Upper Quartile:  77.16499999999999
# Amount Skewness:  16.977724453761024
# Amount Kurtosis:  845.0926455465277
# Amount Min:  0.0
# Amount Max:  25691.16

# %% [markdown]
# 4) Compute the mean of any column using your own module and compare it with the mean value of
# Pandas.

# %%
print("Mean from Pandas: ", df['Amount'].mean())
a = df['Amount']
print("Mean using my module: ", m.mean(a))
# Out:
# Mean from Pandas:  88.34961925087359
# Mean using my module:  88.34961925087359

# %% [markdown]
# 5) Show the histogram of Time and Amount column.

# %%
df.hist(column = ['Time'], bins = 10, color='b')
df.hist(column = ['Amount'], bins = 10, color='y')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe483bfac50>]],
#       dtype=object)

# %% [markdown]
# 6) Find the percentage of rows with class value = 0 (Non-Fraudulent) and class value = 1 (Fraudulent).

# %%
class0 = len(df[df['Class']==0])*100
class1 = len(df[df['Class']==1])*100

print("Percentage of class value 0 :",class0/len(df['Class']))
print("Percentage of class value 1 :",class1/len(df['Class']))
# Out:
# Percentage of class value 0 : 99.827251436938
# Percentage of class value 1 : 0.1727485630620034

# %% [markdown]
# 7) Show the result you have got in 6 using a histogram.

# %%
df1 = pd.DataFrame({'lab':['Fraud', 'Non Fraud'], 'val':[class0, class1]})
ax = df1.plot.bar(x='lab', y='val', rot=0, color='y')

# %% [markdown]
# 8) Show the histrogram (data distribution) of a few other columns. Differentiate between left-skewed
# and right-skewed distributions.

# %%
from pandas.core.frame import DataFrame
df.hist(column = ["V10", "V12", "V13"], bins = 20, color='y')
V23_length = df[['V10']]
print("Skewness: " , V23_length.skew())

V22_length = df[['V11']]
print("Skewness: " , V22_length.skew())

V19_length = df[['V13']]
print("Skewness: " , V19_length.skew())
# Out:
# Skewness:  V10    1.187141
# dtype: float64
# Skewness:  V11    0.356506
# dtype: float64
# Skewness:  V13    0.065233
# dtype: float64

# %% [markdown]
# 9) Find positive correlations among columns.

# %%
correlation= df.corr()
positive_corr= correlation[df.corr() > 0]
print(positive_corr)
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01           NaN           NaN           NaN
# V1      0.117396  1.000000e+00  4.135835e-16           NaN           NaN
# V2           NaN  4.135835e-16  1.000000e+00  3.243764e-16           NaN
# V3           NaN           NaN  3.243764e-16  1.000000e+00  4.711293e-16
# V4           NaN           NaN           NaN  4.711293e-16  1.000000e+00
# V5      0.173072  1.812612e-17  5.157519e-16           NaN           NaN
# V6           NaN           NaN  2.787346e-16  1.627627e-15           NaN
# V7      0.084714           NaN  2.055934e-16  4.895305e-16           NaN
# V8           NaN           NaN           NaN           NaN  5.697192e-16
# V9           NaN           NaN  1.978488e-17  5.568367e-16  6.923247e-16
# V10     0.030617  7.388135e-17           NaN  1.156587e-15  2.232685e-16
# V11          NaN  2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16
# ...

# %% [markdown]
# 10) Support your findings in Question 9 using a BoxPlot.

# %%
positive_corr.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# 11) Support your findings in Question 9 using a Scatter Plot.

# %%
positive_corr.plot.scatter(x= 'Time', y='V1',c='y')

# %% [markdown]
# 12) Find negative correlations among columns.

# %%
negative_correlation= correlation[correlation<0]
st=negative_correlation.unstack()
sort= st.sort_values(kind="quicksort", ascending=False)
print(sort)
# Out:
# V22    V6       -4.705235e-19
# V6     V22      -4.705235e-19
# V4     V28      -2.761403e-18
# V28    V4       -2.761403e-18
# V12    V7       -3.536655e-18
#                      ...
# Class  V26                NaN
#        V27                NaN
#        V28                NaN
#        Amount             NaN
#        Class              NaN
# Length: 961, dtype: float64

# %% [markdown]
# 13) Support your findings in Question 10 using a BoxPlot.

# %%
negative_correlation.boxplot()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
# 14) Support your findings in Question 9 using a Scatter Plot.

# %%
positive_corr.plot.scatter(x= 'Time', y='V1',c='c')
